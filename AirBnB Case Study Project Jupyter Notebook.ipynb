# %% [markdown]
# # AirBnB NY Locations Data Case Study
#
# In this final project, you task will be to take the data provided and find evidance to answer the following questions.
#
# 1. Which hosts are the busiest and why?
# 2. How many neighborhood groups are available and which shows up the most?
# 3. Are private rooms the most popular in manhattan?
# 4. Which hosts are the busiest and based on their reviews?
# 5. Which neighorhood group has the highest average price?
# 6. Which neighborhood group has the highest total price?
# 7. Which top 5 hosts have the highest total price?
# 8. Who currently has no (zero) availability with a review count of 100 or more?
# 9. What host has the highest total of prices and where are they located?
# 10. When did Danielle from Queens last receive a review?
#
#
# This is to similute what you will face when you are out in the wild.
#
# Happy Coding!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_bnb = pd.read_csv('AB_NYC_2019.csv')
air_bnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# How many neighborhood groups are available and which shows up the most?
air_bnb.groupby('neighbourhood_group').count()
# there are 5 neighborhood groups available and Manhattan shows up the most
# Out:
#                         id   name  host_id  host_name  neighbourhood  \
# neighbourhood_group
# Bronx                 1091   1090     1091       1090           1091
# Brooklyn             20104  20098    20104      20095          20104
# Manhattan            21661  21652    21661      21652          21661
# Queens                5666   5666     5666       5664           5666
# Staten Island          373    373      373        373            373
#
#                      latitude  longitude  room_type  price  minimum_nights  \
# neighbourhood_group
# Bronx                    1091       1091       1091   1091            1091
# Brooklyn                20104      20104      20104  20104           20104
# Manhattan               21661      21661      21661  21661           21661
# Queens                   5666       5666       5666   5666            5666
# Staten Island             373        373        373    373             373
#
# ...

# %%
# Are private rooms the most popular in manhattan?
air_bnb.groupby(['neighbourhood_group', 'room_type']).count()
# No. Entire home/apt is more popular
# Out:
#                                         id   name  host_id  host_name  \
# neighbourhood_group room_type
# Bronx               Entire home/apt    379    379      379        378
#                     Private room       652    652      652        652
#                     Shared room         60     59       60         60
# Brooklyn            Entire home/apt   9559   9558     9559       9554
#                     Private room     10132  10127    10132      10128
#                     Shared room        413    413      413        413
# Manhattan           Entire home/apt  13199  13193    13199      13196
#                     Private room      7982   7979     7982       7976
#                     Shared room        480    480      480        480
# Queens              Entire home/apt   2096   2096     2096       2096
#                     Private room      3372   3372     3372       3370
#                     Shared room        198    198      198        198
# ...

# %%
# Which hosts are the busiest and based on their reviews?
air_bnb.groupby('host_name').sum().sort_values('number_of_reviews', ascending = False).head()
# top 5 hosts based on reviews below
# Out:
#                    id      host_id     latitude    longitude  price  \
# host_name
# Michael    7430617239  22673153604  16984.89137 -30841.28573  66895
# David      7943862898  28633613354  16414.34392 -29804.53757  65844
# John       5737372154  24525297065  11974.02914 -21743.58993  41892
# Jason      2176696732   6962647849   5700.22907 -10354.60535  19381
# Alex       5496620312  19850092761  11361.10533 -20635.86235  52563
#
#            minimum_nights  number_of_reviews  reviews_per_month  \
# host_name
# Michael              4600              11081             475.82
# David                3754               8103             508.61
# John                 2603               7223             321.02
# Jason                1193               6522             196.15
# Alex                 1651               6204             443.44
#
#            calculated_host_listings_count  availability_365
# host_name
# Michael                              1043             38888
# ...

# %%
#Which neighorhood group has the highest average price?
air_bnb.groupby('neighbourhood_group').mean().sort_values('price', ascending = False)['price']
# Manhattan
# Out:
# neighbourhood_group
# Manhattan        196.875814
# Brooklyn         124.383207
# Staten Island    114.812332
# Queens            99.517649
# Bronx             87.496792
# Name: price, dtype: float64

# %%
# Which neighbor hood group has the highest total price?
air_bnb.groupby('neighbourhood_group').sum().sort_values('price', ascending = False)['price']
# Manhattan
# Out:
# neighbourhood_group
# Manhattan        4264527
# Brooklyn         2500600
# Queens            563867
# Bronx              95459
# Staten Island      42825
# Name: price, dtype: int64

# %%
#Which top 5 hosts have the highest total price?
air_bnb.groupby('host_name').sum().sort_values('price', ascending = False).head()
# Out:
#                        id      host_id     latitude    longitude  price  \
# host_name
# Sonder (NYC)  10885561678  71782340547  13316.25823 -24198.18856  82795
# Blueground     7210036953  24924786136   9451.60418 -17166.13165  70331
# Michael        7430617239  22673153604  16984.89137 -30841.28573  66895
# David          7943862898  28633613354  16414.34392 -29804.53757  65844
# Alex           5496620312  19850092761  11361.10533 -20635.86235  52563
#
#               minimum_nights  number_of_reviews  reviews_per_month  \
# host_name
# Sonder (NYC)            4353               1281             397.56
# Blueground              7470                 29               6.04
# Michael                 4600              11081             475.82
# David                   3754               8103             508.61
# Alex                    1651               6204             443.44
#
#               calculated_host_listings_count  availability_365
# host_name
# ...

# %%
# Who currently has no (zero) availability with a review count of 100 or more?

air2 = air_bnb[air_bnb['number_of_reviews'] >= 100]
air2[air2['availability_365'] == 0]
# Out:
#              id                                       name    host_id  \
# 8          5203         Cozy Clean Guest Room - Family Apt       7490
# 94        20913         Charming 1 bed GR8 WBurg LOCATION!      79402
# 132       30031           NYC artists’ loft with roof deck     129352
# 174       44221             Financial District Luxury Loft     193722
# 180       45556      Fort Greene, Brooklyn: Center Bedroom      67778
# ...         ...                                        ...        ...
# 29581  22705516         The Quietest Block in Manhattan :)  127740507
# 30461  23574142                          queens get away!!  176185168
# 31250  24267706  entire sunshine of the spotless mind room   21074914
# 32670  25719044                COZY Room for Female Guests   40119874
# 35014  27759146     Cozy corner near Empire State Building  209549523
#
#         host_name neighbourhood_group              neighbourhood  latitude  \
# ...

# %%
# What host has the highest total of prices and where are they located?
air_bnb.groupby('host_name').sum().sort_values('price', ascending = False)
# Sonder (NYC)
air_bnb[air_bnb['host_name'] == 'Sonder (NYC)']
# From Manhattan
# Out:
#              id                                               name    host_id  \
# 38293  30181691      Sonder | 180 Water | Incredible 2BR + Rooftop  219517861
# 38294  30181945         Sonder | 180 Water | Premier 1BR + Rooftop  219517861
# 38588  30347708        Sonder | 180 Water | Charming 1BR + Rooftop  219517861
# 39769  30937590            Sonder | The Nash | Artsy 1BR + Rooftop  219517861
# 39770  30937591        Sonder | The Nash | Lovely Studio + Rooftop  219517861
# ...         ...                                                ...        ...
# 47691  35871510  Sonder | 116 John | Vibrant Studio + Fitness Room  219517861
# 47692  35871511     Sonder | 116 John | Vibrant 1BR + Fitness Room  219517861
# 47693  35871515         Sonder | 116 John | Stunning 1BR + Rooftop  219517861
# 47814  35936418          Sonder | 116 John | Polished Studio + Gym  219517861
# 47821  35937891            Sonder | 116 John | Simple Studio + Gym  219517861
#
# ...

# %%
# When did Danielle from Queens last receive a review?
danielle = air_bnb[air_bnb['host_name'] == 'Danielle']
danielle[danielle['neighbourhood_group'] == 'Queens'].sort_values('last_review', ascending = False)
# 2019-07-08
# Out:
#              id                                               name    host_id  \
# 22469  18173787  Cute Tiny Room Family Home by LGA NO CLEANING FEE   26432133
# 21517  17222454   Sun Room Family Home LGA Airport NO CLEANING FEE   26432133
# 20403  16276632  Cozy Room Family Home LGA Airport NO CLEANING FEE   26432133
# 22068  17754072                Bed in Family Home Near LGA Airport   26432133
# 7086    5115372  Comfy Room Family Home LGA Airport NO CLEANING...   26432133
# 33861  26814763  One bedroom with full bed / 1 stop from Manhattan  201647469
# 27021  21386105  Quiet & clean 1br haven with balcony near the ...  154256662
# 16349  13151075                    ASTORIA APARTMENT OUTDOOR SPACE   18051286
#
#       host_name neighbourhood_group     neighbourhood  latitude  longitude  \
# 22469  Danielle              Queens     East Elmhurst  40.76380  -73.87238
# 21517  Danielle              Queens     East Elmhurst  40.76367  -73.87088
# ...

# %% [markdown]
# ## Further Questions
#
# 1. Which host has the most listings?

# %%
air_bnb.groupby('host_name').count().sort_values('id', ascending = False)
# Michael
# Out:
#                id  name  host_id  neighbourhood_group  neighbourhood  \
# host_name
# Michael       417   417      417                  417            417
# David         403   403      403                  403            403
# Sonder (NYC)  327   327      327                  327            327
# John          294   294      294                  294            294
# Alex          279   279      279                  279            279
# ...           ...   ...      ...                  ...            ...
# Jerbean         1     1        1                    1              1
# Jerald          1     1        1                    1              1
# Jeonghoon       1     1        1                    1              1
# Jeny            1     1        1                    1              1
# 현선              1     1        1                    1              1
#
#               latitude  longitude  room_type  price  minimum_nights  \
# host_name
# ...

# %% [markdown]
# 2. How many listings have completely open availability?

# %%
air_bnb[air_bnb['availability_365'] == 365]
# 48887
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 36        11452                        Clean and Quiet in Brooklyn       7355
# 38        11943                          Country space in the city      45445
# 97        21644                          Upper Manhattan, New York      82685
# ...         ...                                                ...        ...
# 48744  36415840         A BEAUTIFUL SPACE IN HEART OF WILLIAMSBURG  223715460
# 48844  36453952    West Village Studio on quiet cobblestone street  115491896
# 48868  36473253                       Heaven for you(only for guy)  261338177
# 48880  36481315  The Raccoon Artist Studio in Williamsburg New ...  208514239
# 48887  36483152    Garden Jewel Apartment in Williamsburg New York  208514239
#
# ...

# %% [markdown]
# 3. What room_types have the highest review numbers?

# %%
air_bnb.groupby('room_type').mean().sort_values('number_of_reviews', ascending = False)
# Private room
# Out:
#                            id       host_id   latitude  longitude       price  \
# room_type
# Private room     1.946893e+07  7.247514e+07  40.729208 -73.942924   89.780973
# Entire home/apt  1.843818e+07  6.175593e+07  40.728649 -73.960696  211.794246
# Shared room      2.300378e+07  1.026241e+08  40.730514 -73.943343   70.127586
#
#                  minimum_nights  number_of_reviews  reviews_per_month  \
# room_type
# Private room           5.377900          24.112962           1.445209
# Entire home/apt        8.506907          22.842418           1.306578
# Shared room            6.475000          16.600000           1.471726
#
#                  calculated_host_listings_count  availability_365
# room_type
# Private room                           3.227717        111.203933
# Entire home/apt                       10.698335        111.920304
# Shared room                            4.662931        162.000862

# %% [markdown]
# # Final Conclusion
#
# In this cell, write your final conclusion for each of the questions asked.
#
# Also, if you uncovered some more details that were not asked above, please discribe them here.
#
# -- Add your conclusion --
